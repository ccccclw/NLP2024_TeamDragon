# %%
from torchtext.data.metrics import bleu_score
candidate_corpus = [['My', 'full','pytorch', 'test']]
references_corpus = [[['My', 'full', 'pytorch', 'test']]]
bleu_score(candidate_corpus, references_corpus)
#BLEU Test

# %%
from torchtext.data.metrics import bleu_score

# 1-gram bleu
with open('candidate40.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references correct priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of lines in the two files is different"

bleu_scores = []

for i in range(len(candidate_corpus)):
    candidate = [candidate_corpus[i]]
    reference = [[references_corpus[i]]]
    bleu = bleu_score(candidate, reference)
    bleu_scores.append(bleu)
    print(f'第{i+1}行BLEU分数: {bleu:.4f}')

avg_bleu = sum(bleu_scores) / len(bleu_scores)
print(f'1-gram BLEU Mean: {avg_bleu:.4f}')

# %%
from torchtext.data.metrics import bleu_score

# 2-gram bleu
with open('candidate.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references correct priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

# 确保两个文件行数相同
assert len(candidate_corpus) == len(references_corpus), "The number of lines in the two files is different"

bleu_scores = []

for i in range(len(candidate_corpus)):
    candidate = [candidate_corpus[i]]
    reference = [[references_corpus[i]]]
    bleu = bleu_score(candidate, reference, max_n=2, weights=[0.7, 0.3])
    bleu_scores.append(bleu)
    print(f'第{i+1}行2-gram BLEU分数: {bleu:.4f}')

avg_bleu = sum(bleu_scores) / len(bleu_scores)
print(f'2-gram BLEU Mean: {avg_bleu:.4f}')
# Out:
# 第1行2-gram BLEU分数: 0.3434
# 第2行2-gram BLEU分数: 0.3434
# 第3行2-gram BLEU分数: 0.2807
# 第4行2-gram BLEU分数: 0.0000
# 第5行2-gram BLEU分数: 0.3434
# 第6行2-gram BLEU分数: 0.2807
# 第7行2-gram BLEU分数: 0.2807
# 第8行2-gram BLEU分数: 0.3434
# 第9行2-gram BLEU分数: 0.0000
# 第10行2-gram BLEU分数: 0.2807
# 第11行2-gram BLEU分数: 0.3434
# 第12行2-gram BLEU分数: 0.0000
# 第13行2-gram BLEU分数: 0.3434
# 第14行2-gram BLEU分数: 0.2807
# 第15行2-gram BLEU分数: 0.3434
# 第16行2-gram BLEU分数: 0.3434
# 第17行2-gram BLEU分数: 0.3434
# 第18行2-gram BLEU分数: 0.4942
# 第19行2-gram BLEU分数: 0.2807
# 第20行2-gram BLEU分数: 0.2807
# 第21行2-gram BLEU分数: 0.3434
# 第22行2-gram BLEU分数: 0.4942
# 第23行2-gram BLEU分数: 0.3434
# 第24行2-gram BLEU分数: 0.3434
# 第25行2-gram BLEU分数: 0.3434
# 第26行2-gram BLEU分数: 0.2807
# 第27行2-gram BLEU分数: 0.3030
# 第28行2-gram BLEU分数: 0.3434
# 第29行2-gram BLEU分数: 0.0000
# 第30行2-gram BLEU分数: 0.3434
# 第31行2-gram BLEU分数: 0.3948
# 第32行2-gram BLEU分数: 0.0000
# 第33行2-gram BLEU分数: 0.3948
# 第34行2-gram BLEU分数: 0.0000
# 第35行2-gram BLEU分数: 0.2799
# 第36行2-gram BLEU分数: 0.0000
# ...

# %%
from torchtext.data.metrics import bleu_score

# 3-gram bleu

with open('candidate40.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references correct priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of lines in the two files is different"

bleu_scores = []

for i in range(len(candidate_corpus)):
    candidate = [candidate_corpus[i]]
    reference = [[references_corpus[i]]]
    bleu = bleu_score(candidate, reference, max_n=3, weights=[0.2, 0.1, 0.7])
    bleu_scores.append(bleu)
    print(f'第{i+1}行3-gram BLEU分数: {bleu:.4f}')

avg_bleu = sum(bleu_scores) / len(bleu_scores)
print(f'3-gram BLEU Mean: {avg_bleu:.4f}')

# %%
from torchtext.data.metrics import bleu_score

# 4-gram bleu
with open('candidate40.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references correct priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of lines in the two files is different"

bleu_scores = []

for i in range(len(candidate_corpus)):
    candidate = [candidate_corpus[i]]
    reference = [[references_corpus[i]]]
    bleu = bleu_score(candidate, reference, max_n=4, weights=[0.1, 0.2, 0.3, 0.4])
    bleu_scores.append(bleu)
    print(f'第{i+1}行4-gram BLEU分数: {bleu:.4f}')

avg_bleu = sum(bleu_scores) / len(bleu_scores)
print(f'所有句子4-gram BLEU分数平均值: {avg_bleu:.4f}')

# %%
from torchtext.data.metrics import bleu_score
import csv

with open('candidate.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of rows in the two files is different"

with open('bleu_scores_correct_translate.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Row', 'BLEU Score'])

    for i in range(len(candidate_corpus)):
        candidate = [candidate_corpus[i]]
        reference = [[references_corpus[i]]]
        bleu = bleu_score(candidate, reference, max_n=3, weights=[1/3, 1/3, 1/3])
        csvwriter.writerow([i+1, bleu])

# %%
from torchtext.data.metrics import bleu_score
import csv

with open('candidate40.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references correct priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of rows in the two files is different"

with open('bleu_scores_correct_priming.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Row', 'BLEU Score'])

    for i in range(len(candidate_corpus)):
        candidate = [candidate_corpus[i]]
        reference = [[references_corpus[i]]]
        bleu = bleu_score(candidate, reference, max_n=4, weights=[5/9, 3/9, 1/9])
        csvwriter.writerow([i+1, bleu])

# %%
with open('candidate40.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references wrong priming.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of rows in the two files is different"

with open('bleu_scores_wrong_priming.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Row', 'BLEU Score'])

    for i in range(len(candidate_corpus)):
        candidate = [candidate_corpus[i]]
        reference = [[references_corpus[i]]]
        bleu = bleu_score(candidate, reference, max_n=3, weights=[5/9, 3/9, 1/9])
        csvwriter.writerow([i+1, bleu])

# %%
with open('candidate.txt', 'r', encoding='utf-8') as f:
    candidate_corpus = [line.strip().split() for line in f]

with open('references wrong translation.txt', 'r', encoding='utf-8') as f:
    references_corpus = [line.strip().split() for line in f]

assert len(candidate_corpus) == len(references_corpus), "The number of rows in the two files is different"

with open('bleu_scores_wrong_translation.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Row', 'BLEU Score'])

    for i in range(len(candidate_corpus)):
        candidate = [candidate_corpus[i]]
        reference = [[references_corpus[i]]]
        bleu = bleu_score(candidate, reference, max_n=3, weights=[1/3, 1/3, 1/3])
        csvwriter.writerow([i+1, bleu])
